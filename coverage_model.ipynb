# %% [markdown]
# # Earth Satellite Coverage Model
#
# This Earth Satellite Coverage Model is built atop of the [Satellite Propagation Toolkit](https://github.com/rufusclark/Satellite-Propagation-Toolkit). To execute place and run this file from the root directory of the toolkit.
#
# Comments, Limitations and Considerations
# - The data presented in this analysis is for a single time point and the distribution of satellite throughout the Earth varies greatly as a function of time
# - This model does not take into account the actual observation angle of optics, but rather uses the estimated observable angle, thus overestimating the area actually observed
# - This model uses all satellites under the CelesTrak "Weather & Earth Resources Satellites" header

# %%
# install dependencies
# %pip install -r requirements.txt
# %pip install cartopy

# restart kernel (with new dependencies)
from IPython.display import display, Javascript
display(Javascript('IPython.notebook.kernel.restart()'))
# Out:
# Requirement already satisfied: skyfield in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 1)) (1.49)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pyserial in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: typing_extensions in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 3)) (4.14.1)
# Requirement already satisfied: geocoder in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 4)) (1.38.1)
# Requirement already satisfied: requests in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: bs4 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 6)) (0.0.2)
# Requirement already satisfied: opencv-python in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 7)) (4.12.0.88)
# Requirement already satisfied: scikit-learn in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: imageio in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 9)) (2.34.2)
# Requirement already satisfied: reportlab in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 10)) (4.4.3)
# Requirement already satisfied: flask in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 11)) (3.1.1)
# Requirement already satisfied: flask-compress in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 12)) (1.18)
# Requirement already satisfied: waitress in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 14)) (3.9.0)
# Requirement already satisfied: numpy in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 15)) (2.2.6)
# Requirement already satisfied: tabulate in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: scipy in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 17)) (1.14.1)
# Requirement already satisfied: flask-limiter in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 18)) (4.0.0)
# Requirement already satisfied: textwrap3 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 19)) (0.9.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from skyfield->-r requirements.txt (line 1)) (2024.6.2)
# Requirement already satisfied: jplephem>=2.13 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from skyfield->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: sgp4>=2.2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from skyfield->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: click in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geocoder->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: future in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geocoder->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geocoder->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: six in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from geocoder->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->-r requirements.txt (line 5)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bs4->-r requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from imageio->-r requirements.txt (line 9)) (10.3.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask->-r requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask->-r requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask->-r requirements.txt (line 11)) (2.1.5)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask->-r requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: brotli in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask-compress->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: pyzstd in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask-compress->-r requirements.txt (line 12)) (0.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 14)) (2.8.2)
# Requirement already satisfied: limits>=3.13 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask-limiter->-r requirements.txt (line 18)) (5.6.0)
# Requirement already satisfied: ordered-set<5,>4 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask-limiter->-r requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: rich<15,>=12 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from flask-limiter->-r requirements.txt (line 18)) (14.2.0)
# Requirement already satisfied: colorama in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click->geocoder->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: deprecated>=1.2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from limits>=3.13->flask-limiter->-r requirements.txt (line 18)) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich<15,>=12->flask-limiter->-r requirements.txt (line 18)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich<15,>=12->flask-limiter->-r requirements.txt (line 18)) (2.17.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 6)) (2.7)
# Requirement already satisfied: decorator in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ratelim->geocoder->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: wrapt<3,>=1.10 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecated>=1.2->limits>=3.13->flask-limiter->-r requirements.txt (line 18)) (2.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from markdown-it-py>=2.2.0->rich<15,>=12->flask-limiter->-r requirements.txt (line 18)) (0.1.2)
# [notice] A new release of pip is available: 24.1 -> 25.3
# [notice] To update, run: C:\Users\rufus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: cartopy in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (2.2.6)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (3.9.0)
# Requirement already satisfied: shapely>=2.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (3.0.2.post1)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyproj>=3.3.1->cartopy) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\rufus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 25.3
# [notice] To update, run: C:\Users\rufus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# import all dependencies
from src import init_sats, SGP4Propagation, plot_orbital_overview, OrbitalPosition
from src.const import EARTH_RADIUS

from datetime import datetime, time
import numpy as np

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from pyproj import Geod

plt.style.use("default")
plt.rcParams.update({
    "mathtext.fontset": "cm",  # Computer Modern
    "font.family": "serif"
})

# %%
# Import satellite data

# Import all sats
sats = init_sats(update_sources=False)

# Number of sats
print(len(sats))

# Print out all satellite categories
sats.print_all_categories()
# Out:
# Using cached source groups
# Loaded all 54 NORAD data sources
# Loaded satcat.csv SATCAT data source
# 13923
# {'communications satellites': 10982,
#  'miscellaneous satellites': 68,
#  'navigation satellites': 164,
#  'scientific satellites': 56,
#  'special-interest satellites': 2147,
#  'weather & earth resources satellites': 506}

# %%
# propagation time - you want this to be within 2 weeks +/- of current data epoch or the output will be unreliable
t = datetime.combine(datetime(2025, 11, 27).date(), time(12)) # today at noon

# Filter sats
sats = sats.filter(lambda sat: sat.category == "weather & earth resources satellites")

# filter out non leo
sats = sats.filter(lambda sat: SGP4Propagation()._propagate(sat, t).geo.alt < 2000)

# Number of sats
print(len(sats))
# Out:
# 387

# %%
# Get satellite position at given time

# Get position at a given time
positions = SGP4Propagation().propagate(sats, t)

# %%
# Optionally, plot orbital overview

plot_orbital_overview(positions)

# %%
# process orbital position data and calculate ground radius

def half_angle(position: OrbitalPosition) -> float:
    """lookup half angle based on Ciara data on constellations field of view"""
    # Ciara data
    lookup_dict = {"FLOCK": {"FoV half angle degs": 1.5, "night mode": False, "instrument": "optical"}, "SKYSAT": {"FoV half angle degs": 7.5, "night mode": False, "instrument": "optical"}, "ICEYE": {"FoV half angle degs": 4.5, "night mode": True, "instrument": "radar"}, "CAPELLA": {"FoV half angle degs": 15, "night mode": True, "instrument": "radar"}, "SENTINEL": {"FoV half angle degs": 15, "night mode": False, "instrument": "optical"}, "WORLDVIEW": {"FoV half angle degs": 1.5, "night mode": False, "instrument": "optical"}, "OTHER": {"FoV half angle degs": 15, "night mode": False, "instrument": "optical"}}
    lookup_dict_keys = list(lookup_dict.keys())
    constellation = position.sat.constellation

    return lookup_dict[constellation if constellation in lookup_dict_keys else "OTHER"]["FoV half angle degs"]

# create numpy array for latitude, longitude and ground radius of each sat
latitudes = np.array([position.geo.lat for position in positions])
longitudes = np.array([position.geo.lon for position in positions])
ground_radius = np.array([position.geo.swath_ground_radius(half_angle(position)) for position in positions])

# %%
# Plot the boundary of coverage on a 2D map

# Earth model for geodesics
geod = Geod(ellps="WGS84")

def geodesic_circle(lon0, lat0, radius_km, n=360):
    # Ensure lon0, lat0, radius are scalars (very important)
    lon0 = float(lon0)
    lat0 = float(lat0)
    radius_m = float(radius_km) * 1000.0

    # Bearings 0–360°
    az = np.linspace(0, 360, n)

    # Create *matching-length* arrays
    lon0_arr = np.full_like(az, lon0, dtype=float)
    lat0_arr = np.full_like(az, lat0, dtype=float)
    dist_arr  = np.full_like(az, radius_m, dtype=float)

    lon, lat, _ = geod.fwd(lon0_arr, lat0_arr, az, dist_arr)

    return lon, lat

# Plot
fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines()

for sat_lats, sat_lons, r in zip(latitudes, longitudes, ground_radius):
    c_lon, c_lat = geodesic_circle(sat_lons, sat_lats, r)
    ax.plot(c_lon, c_lat, transform=ccrs.Geodetic(), linewidth=0.5)

plt.title(f"Boundary current of 'weather & earth resource satellites` ({len(sats)}) as of {t}")

plt.show()

# %%
# define fibonacci grid - almost perfectly distributed points on a sphere
# https://extremelearning.com.au/how-to-evenly-distribute-points-on-a-sphere-more-effectively-than-the-canonical-fibonacci-lattice/

resolution_km = 25

# calculate the number of points needed
n = np.ceil((4 * np.pi * EARTH_RADIUS**2)/(resolution_km)**2)
print(f"Total grid points: {n:.0f}")

# generate fibonacci sphere coordinates
i = np.arange(n)
golden_ratio = (1 + 5**0.5)/2
theta = 2 * np.pi * i / golden_ratio
phi = np.arccos(1 - 2*(i)/n)

# convert to spherical coordinates
x, y, z = np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi)

# convert to lat/lon (degrees)
grid_lats = np.degrees(np.arcsin(y))
grid_lons = np.degrees(np.arctan2(z, x))
# Out:
# Total grid points: 816104

# %%
# plot fibonacci grid

# Plot
fig = plt.figure(figsize=(18, 9))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines()

# Plot the points
ax.scatter(grid_lons, grid_lats, s=0.005, color='red',alpha=0.7,transform=ccrs.Geodetic())

plt.title(f"Fibonacci Sphere Points on Global Map (N={len(grid_lats)})")
plt.show()

# %%
# coverage calculations

def great_circle_distance(lat1, lon1, lat2, lon2):
    """computes the great-circle distance in kilometres.

    uses the spherical law of cosines (accurate when distance is > 1m) otherwise you haversine formula

    typical error vs WGS-64 Ellipsoid is 0.1%-0.5%
    """
    dlon = lon2 - lon1

    return EARTH_RADIUS * np.acos(
        np.sin(lat1) * np.sin(lat2) + np.cos(lat1) * np.cos(lat2) * np.cos(dlon)
    )

coverage = np.zeros(grid_lons.shape, dtype=np.int16)

# precompute values for great circle calculations
grid_lats_rad = np.radians(grid_lats)
grid_lons_rad = np.radians(grid_lons)

for sat_lat, sat_lon, sat_r in zip(latitudes, longitudes, ground_radius):

    # performance optimisations

    # pre-convert
    sat_lat_rad = np.radians(sat_lat)
    sat_lon_rad = np.radians(sat_lon)

    # bounding box calculations
    central_angle = sat_r / EARTH_RADIUS

    # latitude mask
    mask = np.abs(grid_lats_rad - sat_lat_rad) <= central_angle

    # skip if no points in bounding box
    if not np.any(mask):
        continue

    # end of performance optimisations

    # Great circle distance
    dist = great_circle_distance(grid_lats_rad[mask], grid_lons_rad[mask], sat_lat_rad, sat_lon_rad)

    # check if grid point is within sat radius
    coverage[mask] += (dist <= sat_r).astype(np.int16)

# %%
# Plot coverage

fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.Robinson())
ax.coastlines()
sc = ax.scatter(grid_lons, grid_lats, c=coverage, s=10, cmap="viridis", alpha=0.7, transform=ccrs.Geodetic())
plt.colorbar(sc, orientation="vertical", label="Number of satellites covering each point")
plt.title(f"Density of current 'weather & earth resource satellites` ({len(sats)}) coverage as of {t}")
plt.show()

# %%
# Flatten coverage array
max_coverage = coverage.max()

# Compute counts for >= i satellites (no weighting)
counts = np.array([np.sum(coverage >= i) for i in range(1, max_coverage+1)])

# Convert to percentage of total grid points
cumulative_percent = counts / coverage.size * 100
num_sats = np.arange(1, max_coverage+1)

# Add data point (num_sats, cumulative_percent) = (0, 100) to clean up graph
num_sats = np.insert(num_sats, 0, 0)
cumulative_percent = np.insert(cumulative_percent, 0, 100)

# plot coverage cumulative frequency
plt.figure(figsize=(8,5))
plt.plot(num_sats, cumulative_percent)
plt.xlabel("Number of satellites")
plt.ylabel("Global surface coverage (%)")
plt.xlim(0, len(num_sats))
plt.ylim(0, 110)
plt.title(f"Cumulative coverage of current satellites as of {t}")
plt.grid(True, linestyle=":", color="gray")
plt.show()
